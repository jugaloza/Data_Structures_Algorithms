# %% [markdown]
# Array Intersection(nlogn + mlogn)

# %%
def intersection(arr1, arr2):
    # Please add your code here
    mergesort(arr1)
    for i in range(len(arr2)):
        if(binarysearch(arr1,0,len(arr1)-1,arr2[i])):
            print(arr2[i])
    pass
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1
def binarysearch(a1,s,e,x):
    if s>e:
        return False
    mid=(s+e)//2
    if a1[mid]==x:
        return True
    elif a1[mid]>x:
        return binarysearch(a1,s,mid-1,x)
    else:
        return binarysearch(a1,mid+1,e,x)
    
  
 #Main
n1=int(input())
arr1=list(int(i) for i in input().strip().split(' '))
n2=int(input())
arr2=list(int(i) for i in input().strip().split(' '))
intersection(arr1, arr2)
# Out:
# 4
# 3 2 1 4
# 3
# 2 1 4
# 2
# 1
# 4

# %% [markdown]
# Array intersection(nlogn + n)

# %%
def intersection(arr1, arr2):
    # Please add your code here
    mergesort(arr1)
    mergesort(arr2)
    i=j=0
    while i<len(arr1) and j<len(arr2):
        if arr1[i]==arr2[j]:
            print(arr1[i])
            i+=1
            j+=1
        elif arr1[i]<arr2[j]:
            i+=1
        else:
            j+=1
            
    pass
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1

    
  
 #Main
n1=int(input())
arr1=list(int(i) for i in input().strip().split(' '))
n2=int(input())
arr2=list(int(i) for i in input().strip().split(' '))
intersection(arr1, arr2)
# Out:
# 4
# 3 2 1 4
# 3
# 2 1 3
# 1
# 2
# 3

# %% [markdown]
# Array Equilibrium index

# %%
def equilibriumIndex(arr):
    # Please add your code here
    i=0
    j=-1
    sum=left_sum=0
    for i in range(len(arr)):
        sum+=arr[i]
    for i in range(len(arr)):
        sum-=arr[i]
        if(left_sum==sum):
            return i
        left_sum+=arr[i]
    return -1
        
    pass

# Main
n = int(input())
arr = [int(i) for i in input().strip().split()]
print(equilibriumIndex(arr))
# Out:
# 7
# -7 1 5 2 -4 3 0
# 3

# %% [markdown]
# Find unique element

# %%
def FindUnique(arr):
    # Please add your code here
    mergesort(arr)
    i=0
    j=1
    temp=arr[0]
    for i in range(len(arr)):
        if arr[i]!=temp:
            return arr[i]
        temp=arr[i]
    pass
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1
# Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
unique=FindUnique(arr)
print(unique)
# Out:
# 2001
# ...

# %% [markdown]
# Find duplicate number

# %%
def MissingNumber(arr):
    # Please add your code here
    sum=0
    for i in range(len(arr)):
        sum=sum+arr[i]
    return  sum - ((n-2) *(n-1)//2)
 # Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
ans=MissingNumber(arr)
print(ans)
# Out:
# 9
# 0 7 2 5 4 7 1 3 6
# 7

# %% [markdown]
# Pair sum in array

# %%
def pairSum(arr, x):
    # Please add your code here
    mergesort(arr)
    i=0
    j=len(arr)-1
    
    while i<j:
        count1=1
        count2=1
        count3=1
        t=0
        
        if arr[i]+arr[j]==x and arr[i]!=arr[j]:
            temp=arr[i]
            while arr[i+1]==temp:
                count1+=1
                i+=1
            temp=arr[j]
            while arr[j-1]==temp:
                count2+=1
                j-=1
            
            
            if count1*count2>1:
                k=0
                while k<count1*count2:
                    print(arr[i],end=" ")
                    print(arr[j])
                    k+=1
                i+=1
                j-=1
            else:
                print(arr[i],end=" ")
                print(arr[j])
                i+=1
                j-=1
        
        elif arr[i] + arr[j]==x and arr[i]==arr[j]:
            while i<j:
                count3+=1
                i+=1
                
            j-=1
        
           
            while t<(count3*(count3-1))//2:
                print(arr[i-1],end=" ")
                print(arr[j+1])
                t+=1
                
        elif arr[i]+arr[j]<x:
            i+=1
        else:
            j-=1
            
    pass
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1

# Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
sum=int(input())
pairSum(arr, sum)
# Out:
# 9
# 1 2 2 3 3 4 4 5 6
# 5
# 1 4
# 1 4
# 2 3
# 2 3
# 2 3
# 2 3

# %% [markdown]
# Rotate array with d positions

# %%
def Rotate(arr, d):
    i=0
    # Please add your code here
    temp=[]
    for j in range(0,d,1):
        temp.append(arr[j%len(arr)])
    for i in range(0,len(arr)-d,1):
        arr[i]=arr[(i+d)]

    j=0
    i=n-d
    while j<len(temp) and i<len(arr):
        arr[i]=temp[j]
        i+=1
        j+=1
        
        

    pass

# Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
d=int(input())
Rotate(arr, d)
print(*arr)
# Out:
# 194
# 167 354 92 221 16 448 120 53 339 350 62 189 496 117 257 495 378 488 257 53 232 230 1 270 247 212 258 113 303 490 254 228 453 484 120 498 60 332 450 34 112 438 376 56 492 418 120 228 462 218 9 119 321 34 409 206 47 363 474 155 361 77 435 447 409 211 53 441 278 409 82 445 243 430 371 17 44 494 387 405 115 403 110 297 467 370 341 409 449 322 1 369 342 104 21 365 116 463 362 90 351 46 125 203 97 254 54 260 11 267 84 368 311 362 320 247 49 254 57 325 300 150 166 73 244 499 238 392 134 483 499 103 383 300 45 347 488 488 397 91 99 166 357 380 470 497 15 466 3 381 110 98 435 26 241 376 126 392 194 385 95 269 336 113 326 308 191 90 416 201 444 194 438 427 146 88 365 41 455 465 57 333 180 436 244 405 346 256 489 231 367 429 421 137
# 235
# ...

# %% [markdown]
# Triplet sum

# %%
def pairSum(arr, x):
    # Please add your code here
    mergesort(arr)
    i=0
    
    for i in range(0,len(arr)-2):
        l = i+1
        r=len(arr)-1
        
        while l<r:
            count1=1
            count2=1
            count3=1
            t=0
        
            if arr[i]+arr[l]+arr[r]==x and arr[l]!=arr[r]:
                temp=arr[l]
                while arr[l+1]==temp:
                    count1+=1
                    l+=1
                temp=arr[r]
                while arr[r-1]==temp:
                    count2+=1
                    r-=1
            
            
                if count1*count2>1:
                    k=0
                    while k<count1*count2:
                        print(arr[i],end=" ")
                        print(arr[l],end=" ")
                    
                        print(arr[r])
                        k+=1
                    l+=1
                    r-=1
                else:
                    print(arr[i],end=" ")
                    print(arr[l],end=" ")
                    print(arr[r])
                    l+=1
                    r-=1
        
            elif arr[i] +arr[l]+ arr[r]==x and arr[l]==arr[r]:
                while l<r:
                    count3+=1
                    l+=1
                
                r-=1
        
           
                while t<(count3*(count3-1))//2:
                    print(arr[l-1],end=" ")
                    print(arr[l-2],end=" ")
                    print(arr[r+1])
                    t+=1
                
            elif arr[i]+arr[l]+arr[r]<x:
                l+=1
            else:
                r-=1
            
    pass
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1

# Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
sum=int(input())
pairSum(arr, sum)
# Out:
# 6
# 1 2 3 3 3 3
# 5

# %%
def pairSum(arr, x):
    # Please add your code here
    mergesort(arr)
    for i in range(0,len(arr)-2):
        l = i+1
        r = len(arr)-1
        while l<r:
            count1=1
            count2=1
            count3=1
            t=0
            if arr[i]+arr[l]+arr[r]==x:
                temp = arr[r]
                x=r
                while arr[x-1] == temp:
                    count1+=1
                    x-=1
                
                while t < count1:
                    print(arr[i],end=" ")
                    print(arr[l],end=" ")
                    print(arr[r])
                    t+=1
                l+=1
                
            elif arr[i]+arr[l]+arr[r]<x:
                l+=1
            else:
                r-=1
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1

# Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
sum=int(input())
pairSum(arr, sum)
# Out:
# 7
# 1 2 3 4 5 6 7
#   12
# 1 4 7

# %%
def pairSum(arr, x):
    # Please add your code here
    mergesort(arr)
    for i in range(0,len(arr)-2):
        l = i+1
        r = len(arr)-1
        while l<r:
            count1=1
            count2=1
            count3=1
            t=0
            if arr[i]+arr[l]+arr[r]==x and arr[l]==arr[l+1] and arr[r]==arr[r-1]:
                    temp = arr[r]
                    while arr[r-1] == temp:
                        count1+=1
                        r-=1
                    temp = arr[l]
                    while arr[l+1] == temp:
                        count2+=1
                        l+=1
                    
                    while t<count1*count2:
                        print(arr[i],end=" ")
                        print(arr[l],end=" ")
                        print(arr[r])
                        t+=1
                    break
            elif arr[i]+arr[l]+arr[r]==x and arr[r]==arr[r-1]:
                    x=r
                    temp = arr[r]
                    while arr[r-1] == temp:
                        count1+=1
                        r-=1
                    while t<count1:
                        print(arr[i],end=" ")
                        print(arr[l],end=" ")
                        print(arr[r])
                        t+=1
                    l+=1
            elif arr[i]+arr[l]+arr[r]==x and arr[l]==arr[l+1]:
                    x=r
                    temp = arr[l]
                    while arr[l+1] == temp:
                        count2+=1
                        l+=1
                    while t<count2:
                        print(arr[i],end=" ")
                        print(arr[l],end=" ")
                        print(arr[r])
                        t+=1
                    r-=1
            
            
            elif arr[i]+arr[l]+arr[r]==x:
                    print(arr[i],end=" ")
                    print(arr[l],end=" ")
                    print(arr[r])
                    l+=1
                
            elif arr[i]+arr[l]+arr[r]<x:
                l+=1
            else:
                r-=1
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1

# Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
sum=int(input())
pairSum(arr, sum)
# Out:
# 6
# 2 2 2 2 2 2
# 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-cab96f064057> in <module>
#      95 arr=list(int(i) for i in input().strip().split(' '))
#      96 sum=int(input())
# ---> 97 pairSum(arr, sum)
#
# <ipython-input-36-cab96f064057> in pairSum(arr, x)
#      12             if arr[i]+arr[l]+arr[r]==x and arr[l]==arr[l+1] and arr[r]==arr[r-1]:
#      13                     temp = arr[r]
# ---> 14                     while arr[r-1] == temp:
#      15                         count1+=1
#      16                         r-=1
#
# IndexError: list index out of range

# %%
def pairSum(arr, x):
    
    mergesort(arr)
    
    for s in range(0, n - 1):  
          
        # initialize left and right 
        i = s + 1; 
        j = len(arr) - 1; 
        while i<j:
            count1=1
            count2=1
            count3=1
            t=0
        
            if arr[s] + arr[i]+arr[j]==x and arr[i]!=arr[j]:
                temp=arr[i]
                while arr[i+1]==temp:
                    count1+=1
                    i+=1
                temp=arr[j]
                while arr[j-1]==temp:
                    count2+=1
                    j-=1
            
            
                if count1*count2>1:
                    k=0
                    while k<count1*count2:
                        print(arr[s],end=" ")
                        print(arr[i],end=" ")
                        print(arr[j])
                        k+=1
                    i+=1
                    j-=1
                else:
                    print(arr[s],end=" ")
                    print(arr[i],end=" ")
                    print(arr[j])
                    i+=1
                    j-=1
        
            elif arr[s] + arr[i] + arr[j]==x and arr[i]==arr[j]:
                while i<j:
                    count3+=1
                    i+=1
                
                j-=1
        
           
                while t<(count3*(count3-1))//2:
                    print(arr[s],end=" ")
                    print(arr[i-1],end=" ")
                    print(arr[j+1])
                    t+=1
                
            elif arr[s] + arr[i]+arr[j]<x:
                i+=1
            else:
                j-=1
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1

# Main
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
sum=int(input())
pairSum(arr, sum)
# Out:
# 6
# 1 2 2 3 3 3
# 6
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3

# %%
## Read input as specified in the question.
## Print output as specified in the question.
def tripletSum(arr, x):
    # Please add your code here
    mergesort(arr)
    print(arr)    

    

    
def mergesort(arr1):
    if(len(arr1)>1):
        mid=len(arr1)//2
        a1=arr1[:mid]
        a2=arr1[mid:]
        mergesort(a1)
        mergesort(a2)
        merge(a1,a2,arr1)

def merge(a1,a2,a):
    i=j=k=0
    while i<len(a1) and j<len(a2):
        if a1[i]<a2[j]:
            a[k]=a1[i]
            i+=1
            k+=1
        else:
            a[k]=a2[j]
            j+=1
            k+=1
    while i<len(a1):
        a[k]=a1[i]
        i+=1
        k+=1
    while j<len(a2):
        a[k]=a2[j]
        j+=1
        k+=1

n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
sum=int(input())
tripletSum(arr, sum)
# Out:
# 157
# 19 21 2 19 23 17 8 18 29 9 21 20 1 11 27 22 7 7 29 27 12 1 3 21 28 17 8 15 30 17 19 5 27 6 2 18 3 26 21 15 6 17 29 26 16 23 16 29 6 30 24 24 1 13 7 22 17 29 23 16 5 19 25 29 27 23 24 26 22 1 23 10 29 7 12 4 1 24 8 23 4 13 21 13 27 12 13 23 4 4 14 29 29 12 1 24 8 18 6 4 7 18 1 12 1 12 24 30 28 27 21 16 18 14 7 27 9 19 21 9 2 22 10 14 20 4 12 19 9 17 12 8 11 10 10 14 17 20 14 2 20 26 25 19 22 13 18 7 10 11 25 7 8 1 28 14 10
# 12
# ...
